# %%
import pandas as pd
import gdown

# %%
gdown.download(id='12b-hMXg0V37w4R9bES88YcH7ousM9y9_')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12b-hMXg0V37w4R9bES88YcH7ousM9y9_
# To: /content/tweets.json
# 100%|██████████| 10.6M/10.6M [00:00<00:00, 49.6MB/s]
# 'tweets.json'

# %%
df = pd.read_json('/content/tweets.json')
df = df.transpose(copy=False)

# %%
df.shape
# Out:
# (43347, 2)

# %%
df['tweet_text'].isnull().sum()
# Out:
# 0

# %%
df['tweet_text'] = df['tweet_text'].str.replace(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df['tweet_text'] = df['tweet_text'].str.replace("\W+", " ")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
df['tweet_text']=[i.lower() for i in df['tweet_text']]

# %%
df
# Out:
#                                      tweet_author  \
# 2013-07-18 09:39:46.071961602  Hematopoiesis News
# 2013-07-17 03:40:32.173842437    Michael Wang, MD
# 2013-07-15 15:41:16.553048065         1stOncology
# 2013-07-12 19:19:42.367813635           Toby Eyre
# 2013-07-04 12:40:34.334232586        Lymphoma Hub
# ...                                           ...
# 1987-06-19 12:17:53.643945985  Joy is a Lifestyle
# 1987-06-19 12:06:26.675290112       𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹
# 1987-06-17 23:05:41.186953217               IQWiG
# 1987-06-17 15:18:00.525635584           Medibooks
# 1987-06-13 10:44:06.537678849           Medibooks
#
#                                                                       tweet_text
# 2013-07-18 09:39:46.071961602   scientists conducted a phase ii study of acal...
# 2013-07-17 03:40:32.173842437  this phase 2 acalabrutinib venetoclax av trial...
# 2013-07-15 15:41:16.553048065         nice backs astrazenecas calquence for cll
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('omw-1.4')
lemmatizer = WordNetLemmatizer()

def nltk_tag_to_wordnet_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:          
        return None


def lemmatize_sentence(sentence):
    nltk_tagged = nltk.pos_tag(nltk.word_tokenize(sentence))  

    wordnet_tagged = map(lambda x: (x[0], nltk_tag_to_wordnet_tag(x[1])), nltk_tagged)
    lemmatized_sentence = []
    for word, tag in wordnet_tagged:
        if tag is None:

            lemmatized_sentence.append(word)
        else:        

            lemmatized_sentence.append(lemmatizer.lemmatize(word, tag))
    return " ".join(lemmatized_sentence)


df['tweet_text'] = df['tweet_text'].apply(lambda x: lemmatize_sentence(x))
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
df
# Out:
#                                      tweet_author  \
# 2013-07-18 09:39:46.071961602  Hematopoiesis News
# 2013-07-17 03:40:32.173842437    Michael Wang, MD
# 2013-07-15 15:41:16.553048065         1stOncology
# 2013-07-12 19:19:42.367813635           Toby Eyre
# 2013-07-04 12:40:34.334232586        Lymphoma Hub
# ...                                           ...
# 1987-06-19 12:17:53.643945985  Joy is a Lifestyle
# 1987-06-19 12:06:26.675290112       𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹
# 1987-06-17 23:05:41.186953217               IQWiG
# 1987-06-17 15:18:00.525635584           Medibooks
# 1987-06-13 10:44:06.537678849           Medibooks
#
#                                                                       tweet_text
# 2013-07-18 09:39:46.071961602  scientist conduct a phase ii study of acalabru...
# 2013-07-17 03:40:32.173842437  this phase 2 acalabrutinib venetoclax av trial...
# 2013-07-15 15:41:16.553048065           nice back astrazenecas calquence for cll
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                               index        tweet_author  \
# 0     2013-07-18 09:39:46.071961602  Hematopoiesis News
# 1     2013-07-17 03:40:32.173842437    Michael Wang, MD
# 2     2013-07-15 15:41:16.553048065         1stOncology
# 3     2013-07-12 19:19:42.367813635           Toby Eyre
# 4     2013-07-04 12:40:34.334232586        Lymphoma Hub
# ...                             ...                 ...
# 43342 1987-06-19 12:17:53.643945985  Joy is a Lifestyle
# 43343 1987-06-19 12:06:26.675290112       𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹
# 43344 1987-06-17 23:05:41.186953217               IQWiG
# 43345 1987-06-17 15:18:00.525635584           Medibooks
# 43346 1987-06-13 10:44:06.537678849           Medibooks
#
#                                               tweet_text
# 0      scientist conduct a phase ii study of acalabru...
# 1      this phase 2 acalabrutinib venetoclax av trial...
# 2               nice back astrazenecas calquence for cll
# 3      acalabrutinib be a valuable option in pt intol...
# ...

# %% [markdown]
# Sentiment

# %%
df['overall_polarity']=0

# %%
# !pip install vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 7.6 MB/s
# ...

# %%
obj = SentimentIntensityAnalyzer()

# %%
for i in range(len(df['tweet_text'])):
  di = obj.polarity_scores(df.iloc[i,1])
  c = list(di.values())
  c = c.index(max(c))
  if c == 0:
    df['overall_polarity'][i]='Negative'
  elif c== 1:
    df['overall_polarity'][i]='Neutral'
  elif c == 2:
    df['overall_polarity'][i]='Positive'
  else:
    df['overall_polarity'][i]='compound'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df
# Out:
#                               index        tweet_author  \
# 0     2013-07-18 09:39:46.071961602  Hematopoiesis News
# 1     2013-07-17 03:40:32.173842437    Michael Wang, MD
# 2     2013-07-15 15:41:16.553048065         1stOncology
# 3     2013-07-12 19:19:42.367813635           Toby Eyre
# 4     2013-07-04 12:40:34.334232586        Lymphoma Hub
# ...                             ...                 ...
# 43342 1987-06-19 12:17:53.643945985  Joy is a Lifestyle
# 43343 1987-06-19 12:06:26.675290112       𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹
# 43344 1987-06-17 23:05:41.186953217               IQWiG
# 43345 1987-06-17 15:18:00.525635584           Medibooks
# 43346 1987-06-13 10:44:06.537678849           Medibooks
#
#                                               tweet_text overall_polarity
# 0      scientist conduct a phase ii study of acalabru...          Neutral
# 1      this phase 2 acalabrutinib venetoclax av trial...          Neutral
# ...

# %%
import spacy
from spacy import displacy

NER = spacy.load("en_core_web_sm")

# %%
dit = []

# %%
for i in range(len(df['tweet_text'])):
  raw_text=df['tweet_text'][i]
  text1 = NER(raw_text)
  for word in text1.ents:
    t = []
    t.append(word.text)
    t.append(df.iloc[i,1])
    t.append(df.iloc[i,3])
    dit.append(t)

# %%
newdf = pd.DataFrame(dit,columns=['entity','author_name','overall_polarity'])

# %%
newdf.drop_duplicates(inplace = True)
newdf.reset_index(inplace = True, drop = True)
newdf
# Out:
#                             entity                     author_name  \
# 0                               73              Hematopoiesis News
# 1                                2                Michael Wang, MD
# 2                pharma healthnews  European Pharmaceutical Review
# 3                       tobyeyre82                  Graham Collins
# 4                              cll                     CLL Ireland
# ...                            ...                             ...
# 33748                          600                      Micheál 🇮🇪
# 33749                    liverpool                      Micheál 🇮🇪
# 33750                          cll                   𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹
# 33751  zusatznutzen von idelalisib                           IQWiG
# 33752  hematología ptk2 expression                       Medibooks
#
#       overall_polarity
# 0              Neutral
# 1              Neutral
# 2              Neutral
# 3              Neutral
# 4              Neutral
# ...

# %%
newdf['frequency'] = newdf.groupby('entity')['entity'].transform('count')

# %%
newdf
# Out:
#                             entity                     author_name  \
# 0                               73              Hematopoiesis News
# 1                                2                Michael Wang, MD
# 2                pharma healthnews  European Pharmaceutical Review
# 3                       tobyeyre82                  Graham Collins
# 4                              cll                     CLL Ireland
# ...                            ...                             ...
# 33748                          600                      Micheál 🇮🇪
# 33749                    liverpool                      Micheál 🇮🇪
# 33750                          cll                   𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹
# 33751  zusatznutzen von idelalisib                           IQWiG
# 33752  hematología ptk2 expression                       Medibooks
#
#       overall_polarity  frequency
# 0              Neutral          8
# 1              Neutral        415
# 2              Neutral          1
# ...

# %%
newdf[['entity','frequency']].to_csv('objective1.csv')

# %%
newdf[['entity', 'author_name', 'overall_polarity']].to_csv('objective2.csv')

# %%
sol1 = newdf[['entity','frequency']]
sol1
# Out:
#                             entity  frequency
# 0                               73          8
# 1                                2        415
# 2                pharma healthnews          1
# 3                       tobyeyre82          7
# 4                              cll       1030
# ...                            ...        ...
# 33748                          600         18
# 33749                    liverpool          8
# 33750                          cll       1030
# 33751  zusatznutzen von idelalisib          1
# 33752  hematología ptk2 expression          1
#
# [33753 rows x 2 columns]

# %%
sol2 = newdf[['entity', 'author_name', 'overall_polarity']]
sol2
# Out:
#                             entity                     author_name  \
# 0                               73              Hematopoiesis News
# 1                                2                Michael Wang, MD
# 2                pharma healthnews  European Pharmaceutical Review
# 3                       tobyeyre82                  Graham Collins
# 4                              cll                     CLL Ireland
# ...                            ...                             ...
# 33748                          600                      Micheál 🇮🇪
# 33749                    liverpool                      Micheál 🇮🇪
# 33750                          cll                   𝓒𝓻𝓲𝔃𝔃𝔂 𝓟𝓮𝓻𝓻𝔂🌹
# 33751  zusatznutzen von idelalisib                           IQWiG
# 33752  hematología ptk2 expression                       Medibooks
#
#       overall_polarity
# 0              Neutral
# 1              Neutral
# 2              Neutral
# 3              Neutral
# 4              Neutral
# ...
